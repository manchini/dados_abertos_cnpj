# %%
from src.main import main
import pandas as pd

# %%
main()
# Out:
#                                                   url
# 1   https://arquivos.receitafederal.gov.br/dados/c...
# 2   https://arquivos.receitafederal.gov.br/dados/c...
# 3   https://arquivos.receitafederal.gov.br/dados/c...
# 4   https://arquivos.receitafederal.gov.br/dados/c...
# 5   https://arquivos.receitafederal.gov.br/dados/c...
# 6   https://arquivos.receitafederal.gov.br/dados/c...
# 7   https://arquivos.receitafederal.gov.br/dados/c...
# 8   https://arquivos.receitafederal.gov.br/dados/c...
# 9   https://arquivos.receitafederal.gov.br/dados/c...
# 10  https://arquivos.receitafederal.gov.br/dados/c...
# Baixando arquivo https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj//2025-02/Empresas0.zip para data\raw\2025-02\Empresas\Empresas0.zip
# Baixado: Empresas0.zip
# Baixando arquivo https://arquivos.receitafederal.gov.br/dados/cnpj/dados_abertos_cnpj//2025-02/Empresas1.zip para data\raw\2025-02\Empresas\Empresas1.zip
# Baixado: Empresas1.zip
# ...
