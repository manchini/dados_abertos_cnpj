# %%
import pandas as pd

# %%
df = pd.read_parquet('K3241.K03200Y1.D50111.ESTABELE.parquet')

df.head()
# Out:
#    CNPJ Base  Filial  DV                                 Nome Fantasia  \
# 0     692864       1  11  JM ESCRITORIO DE ASSESSORIA EM CONTABILIDADE
# 1    5092092       1   9                           BUENO DISTRIBUIDORA
# 2    6228465       1  80                         CASA DE CARNES O FILE
# 3    7025967       1  77                                         ELITI
# 4    2161988       1   4                                          None
#
#    Situacao     CNAE                                              CNAE2  UF  \
# 0         2  6920601                                               None  RS
# 1         2  4639701  4623109,4635401,4635402,4635499,4649408,464949...  RS
# 2         2  4722901                                            4712100  RS
# 3         2  4781400                                               None  RS
# 4         2  8112500                                               None  RS
#
#    Municipio  ddd1     fone1  ddd2     fone2  ddd fax       Fax  \
# ...
